# %% [markdown]
# # Drone Count Detection

# %% [markdown]
# **import Libraryes**

# %%
from inference_sdk import InferenceHTTPClient

# %%
CLIENT = InferenceHTTPClient(
    api_url="https://serverless.roboflow.com",
    api_key="77p1eJUJrBPA0nZTIT1I"
)

result = CLIENT.infer("./Image/Drone-Image2.webp", model_id="drone_mil-u8fqk/1")
result
# Out:
# {'inference_id': 'eb0a83fa-5612-493d-81c3-9ecf05e5b664',
#  'time': 0.05330173298716545,
#  'image': {'width': 612, 'height': 408},
#  'predictions': [{'x': 135.0,
#    'y': 68.5,
#    'width': 88.0,
#    'height': 67.0,
#    'confidence': 0.9319899082183838,
#    'class': 'drone',
#    'class_id': 0,
#    'detection_id': 'f430b393-8203-41bf-9e39-819ec4c18b74'},
#   {'x': 277.5,
#    'y': 57.5,
#    'width': 87.0,
#    'height': 65.0,
#    'confidence': 0.9165818095207214,
#    'class': 'drone',
#    'class_id': 0,
#    'detection_id': '57243539-2a0c-4a43-9c7b-5a5f7b18fbab'},
#   {'x': 67.5,
#    'y': 156.5,
#    'width': 87.0,
#    'height': 67.0,
#    'confidence': 0.9158971905708313,
#    'class': 'drone',
#    'class_id': 0,
#    'detection_id': 'f731561e-09e7-41ad-a5b4-43f38f77880c'},
#   {'x': 206.5,
#    'y': 141.5,
#    'width': 87.0,
#    'height': 67.0,
#    'confidence': 0.9100306630134583,
#    'class': 'drone',
#    'class_id': 0,
#    'detection_id': '13ed71d2-4262-4eed-bebc-bff46ff6c361'},
#   {'x': 306.0,
#    'y': 195.0,
#    'width': 88.0,
#    'height': 68.0,
#    'confidence': 0.9060651063919067,
#    'class': 'drone',
#    'class_id': 0,
#    'detection_id': '20a57879-b527-411f-b316-8ad24b668d5d'},
#   {'x': 170.5,
#    'y': 229.5,
#    'width': 91.0,
#    'height': 67.0,
#    'confidence': 0.8963715434074402,
#    'class': 'drone',
#    'class_id': 0,
#    'detection_id': '9543b8fd-20bb-419a-84f9-3293bb3ab417'}]}

# %%
API_result = {}

total_predictions = result['predictions']
API_result["total_predictions"] = len(total_predictions)

API_result["data"] = []

for detection in result['predictions']:
    dict = {}
    
    name = detection["class"]
    dict["name"] = name
    
    confidence = detection["confidence"]
    Confidence_score = f"{confidence:.2f}"
    dict["Confidence_Score"] = Confidence_score
    
    x = detection["x"]
    y = detection["y"]
    w = detection["width"]
    h = detection["height"]
    
    x1 = x - (w / 2)
    y1 = y - (h / 2)
    x2 = x + (w / 2)
    y2 = y + (h / 2)
    
    bounding_box = (x1, y1, x2, y2)
    dict["Bounding_Box"] = bounding_box
    
    API_result["data"].append(dict)

API_result
# Out:
# {'total_predictions': 6,
#  'data': [{'name': 'drone',
#    'Confidence_Score': '0.93',
#    'Bounding_Box': (91.0, 35.0, 179.0, 102.0)},
#   {'name': 'drone',
#    'Confidence_Score': '0.92',
#    'Bounding_Box': (234.0, 25.0, 321.0, 90.0)},
#   {'name': 'drone',
#    'Confidence_Score': '0.92',
#    'Bounding_Box': (24.0, 123.0, 111.0, 190.0)},
#   {'name': 'drone',
#    'Confidence_Score': '0.91',
#    'Bounding_Box': (163.0, 108.0, 250.0, 175.0)},
#   {'name': 'drone',
#    'Confidence_Score': '0.91',
#    'Bounding_Box': (262.0, 161.0, 350.0, 229.0)},
#   {'name': 'drone',
#    'Confidence_Score': '0.90',
#    'Bounding_Box': (125.0, 196.0, 216.0, 263.0)}]}

# %%
import json
json_result = json.dumps(API_result, indent=2)
print(json_result)
# Out:
# {
#   "total_predictions": 6,
#   "data": [
#     {
#       "name": "drone",
#       "Confidence_Score": "0.93",
#       "Bounding_Box": [
#         91.0,
#         35.0,
#         179.0,
#         102.0
#       ]
#     },
#     {
#       "name": "drone",
#       "Confidence_Score": "0.92",
#       "Bounding_Box": [
#         234.0,
#         25.0,
#         321.0,
#         90.0
#       ]
#     },
#     {
#       "name": "drone",
#       "Confidence_Score": "0.92",
#       "Bounding_Box": [
#         24.0,
#         123.0,
#         111.0,
#         190.0
#       ]
#     },
#     {
#       "name": "drone",
#       "Confidence_Score": "0.91",
#       "Bounding_Box": [
#         163.0,
#         108.0,
#         250.0,
#         175.0
#       ]
#     },
#     {
#       "name": "drone",
#       "Confidence_Score": "0.91",
#       "Bounding_Box": [
#         262.0,
#         161.0,
#         350.0,
#         229.0
#       ]
#     },
#     {
#       "name": "drone",
#       "Confidence_Score": "0.90",
#       "Bounding_Box": [
#         125.0,
#         196.0,
#         216.0,
#         263.0
#       ]
#     }
#   ]
# }
